# %%
import dvc.api
import os
import pandas as pd
from pathlib import Path
from importlib_metadata import version
path = r'data\processed\data.csv'
repo = Path(os.getcwd()).parent.parent
version = "v2"

data_csv = dvc.api.read(path=path,repo=repo,rev=version)
# Out:
# ---------------------------------------------------------------------------
# RevError                                  Traceback (most recent call last)
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\dvc\scm.py:140, in resolve_rev(scm, rev)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/scm.py?line=138'>139</a> try:
# --> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/scm.py?line=139'>140</a>     return scm.resolve_rev(fix_exp_head(scm, rev))
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/scm.py?line=140'>141</a> except InternalRevError as exc:
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/scm.py?line=141'>142</a>     # `scm` will only resolve git branch and tag names,
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/scm.py?line=142'>143</a>     # if rev is not a sha it may be an abbreviated experiment name
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\scmrepo\git\__init__.py:289, in Git._backend_func(self, name, *args, **kwargs)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/scmrepo/git/__init__.py?line=287'>288</a> func = getattr(backend, name)
# --> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/scmrepo/git/__init__.py?line=288'>289</a> result = func(*args, **kwargs)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/scmrepo/git/__init__.py?line=289'>290</a> self._last_backend = key
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\scmrepo\git\backend\pygit2.py:297, in Pygit2Backend.resolve_rev(self, rev)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/scmrepo/git/backend/pygit2.py?line=295'>296</a>     return shas.pop()  # type: ignore
# --> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/scmrepo/git/backend/pygit2.py?line=296'>297</a> raise RevError(f"unknown Git revision '{rev}'")
#
# RevError: unknown Git revision 'v2'
#
# During handling of the above exception, another exception occurred:
#
# RevError                                  Traceback (most recent call last)
# c:\Users\aniket.itankar\Desktop\HR_Analytics\notebooks\dvc\retrive_version.ipynb Cell 1' in <cell line: 10>()
#       <a href='vscode-notebook-cell:/c%3A/Users/aniket.itankar/Desktop/HR_Analytics/notebooks/dvc/retrive_version.ipynb#ch0000000?line=6'>7</a> repo = Path(os.getcwd()).parent.parent
#       <a href='vscode-notebook-cell:/c%3A/Users/aniket.itankar/Desktop/HR_Analytics/notebooks/dvc/retrive_version.ipynb#ch0000000?line=7'>8</a> version = "v2"
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aniket.itankar/Desktop/HR_Analytics/notebooks/dvc/retrive_version.ipynb#ch0000000?line=9'>10</a> data_csv = dvc.api.read(path=path,repo=repo,rev=version)
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\dvc\api.py:88, in read(path, repo, rev, remote, mode, encoding)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=81'>82</a> def read(path, repo=None, rev=None, remote=None, mode="r", encoding=None):
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=82'>83</a>     """
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=83'>84</a>     Returns the contents of a tracked file (by DVC or Git). For Git repos, HEAD
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=84'>85</a>     is used unless a rev argument is supplied. The default remote is tried
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=85'>86</a>     unless a remote argument is supplied.
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=86'>87</a>     """
# ---> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=87'>88</a>     with open(
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=88'>89</a>         path, repo=repo, rev=rev, remote=remote, mode=mode, encoding=encoding
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=89'>90</a>     ) as fd:
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=90'>91</a>         return fd.read()
#
# File ~\AppData\Local\Programs\Python\Python38\lib\contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     <a href='file:///c%3A/Users/aniket.itankar/AppData/Local/Programs/Python/Python38/lib/contextlib.py?line=110'>111</a> del self.args, self.kwds, self.func
#     <a href='file:///c%3A/Users/aniket.itankar/AppData/Local/Programs/Python/Python38/lib/contextlib.py?line=111'>112</a> try:
# --> <a href='file:///c%3A/Users/aniket.itankar/AppData/Local/Programs/Python/Python38/lib/contextlib.py?line=112'>113</a>     return next(self.gen)
#     <a href='file:///c%3A/Users/aniket.itankar/AppData/Local/Programs/Python/Python38/lib/contextlib.py?line=113'>114</a> except StopIteration:
#     <a href='file:///c%3A/Users/aniket.itankar/AppData/Local/Programs/Python/Python38/lib/contextlib.py?line=114'>115</a>     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\dvc\api.py:75, in _open(path, repo, rev, remote, mode, encoding)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=73'>74</a> def _open(path, repo=None, rev=None, remote=None, mode="r", encoding=None):
# ---> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=74'>75</a>     with Repo.open(repo, rev=rev, subrepos=True, uninitialized=True) as _repo:
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=75'>76</a>         with _repo.open_by_relpath(
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=76'>77</a>             path, remote=remote, mode=mode, encoding=encoding
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=77'>78</a>         ) as fd:
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/api.py?line=78'>79</a>             yield fd
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\dvc\repo\__init__.py:233, in Repo.open(url, *args, **kwargs)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=230'>231</a> if os.path.exists(url):
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=231'>232</a>     try:
# --> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=232'>233</a>         return Repo(url, *args, **kwargs)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=233'>234</a>     except NotDvcRepoError:
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=234'>235</a>         pass  # fallthrough to external_repo
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\dvc\repo\__init__.py:175, in Repo.__init__(self, root_dir, fs, rev, subrepos, uninitialized, config, url, repo_factory)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=171'>172</a>     self._scm = SCM(root_dir or os.curdir)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=172'>173</a>     self._fs = GitFileSystem(scm=self._scm, rev=rev)
# --> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=174'>175</a> self.root_dir, self.dvc_dir, self.tmp_dir = self._get_repo_dirs(
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=175'>176</a>     root_dir=root_dir, fs=self.fs, uninitialized=uninitialized
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=176'>177</a> )
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=178'>179</a> self.config = Config(self.dvc_dir, fs=self.fs, config=config)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=179'>180</a> self._uninitialized = uninitialized
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\dvc\repo\__init__.py:95, in Repo._get_repo_dirs(self, root_dir, fs, uninitialized)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=92'>93</a> tmp_dir = None
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=93'>94</a> try:
# ---> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=94'>95</a>     root_dir = self.find_root(root_dir, fs)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=95'>96</a>     dvc_dir = os.path.join(root_dir, self.DVC_DIR)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=96'>97</a>     tmp_dir = os.path.join(dvc_dir, "tmp")
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\dvc\repo\__init__.py:319, in Repo.find_root(cls, root, fs)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=315'>316</a> root_dir = os.path.realpath(root)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=316'>317</a> fs = fs or localfs
# --> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=318'>319</a> if not fs.isdir(root_dir):
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=319'>320</a>     raise NotDvcRepoError(f"directory '{root}' does not exist")
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/repo/__init__.py?line=321'>322</a> while True:
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\dvc\fs\base.py:168, in FileSystem.isdir(self, path)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/fs/base.py?line=166'>167</a> def isdir(self, path: AnyFSPath) -> bool:
# --> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/fs/base.py?line=167'>168</a>     return self.fs.isdir(path)
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\funcy\objects.py:50, in wrap_prop.<locals>.decorator.<locals>.WrapperProp.__get__(self, instance, type)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/funcy/objects.py?line=46'>47</a>     return self
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/funcy/objects.py?line=48'>49</a> with ctx:
# ---> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/funcy/objects.py?line=49'>50</a>     return prop.__get__(instance, type)
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\funcy\objects.py:28, in cached_property.__get__(self, instance, type)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/funcy/objects.py?line=25'>26</a> if instance is None:
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/funcy/objects.py?line=26'>27</a>     return self
# ---> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/funcy/objects.py?line=27'>28</a> res = instance.__dict__[self.fget.__name__] = self.fget(instance)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/funcy/objects.py?line=28'>29</a> return res
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\dvc\fs\git.py:48, in GitFileSystem.fs(self)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/fs/git.py?line=42'>43</a> @wrap_prop(threading.Lock())
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/fs/git.py?line=43'>44</a> @cached_property
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/fs/git.py?line=44'>45</a> def fs(self) -> "FsspecGitFileSystem":
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/fs/git.py?line=45'>46</a>     from scmrepo.fs import GitFileSystem as FsspecGitFileSystem
# ---> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/fs/git.py?line=47'>48</a>     return FsspecGitFileSystem(**self.fs_args)
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\fsspec\spec.py:68, in _Cached.__call__(cls, *args, **kwargs)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/fsspec/spec.py?line=65'>66</a>     return cls._cache[token]
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/fsspec/spec.py?line=66'>67</a> else:
# ---> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/fsspec/spec.py?line=67'>68</a>     obj = super().__call__(*args, **kwargs)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/fsspec/spec.py?line=68'>69</a>     # Setting _fs_token here causes some static linters to complain.
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/fsspec/spec.py?line=69'>70</a>     obj._fs_token_ = token
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\scmrepo\fs.py:54, in GitFileSystem.__init__(self, path, rev, scm, trie, rev_resolver, **kwargs)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/scmrepo/fs.py?line=51'>52</a> scm = scm or Git(path)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/scmrepo/fs.py?line=52'>53</a> resolver = rev_resolver or Git.resolve_rev
# ---> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/scmrepo/fs.py?line=53'>54</a> resolved = resolver(scm, rev or "HEAD")
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/scmrepo/fs.py?line=54'>55</a> tree_obj = scm.pygit2.get_tree_obj(rev=resolved)
#      <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/scmrepo/fs.py?line=55'>56</a> trie = GitTrie(tree_obj, resolved)
#
# File c:\Users\aniket.itankar\Desktop\HR_Analytics\env\lib\site-packages\dvc\scm.py:157, in resolve_rev(scm, rev)
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/scm.py?line=153'>154</a>     if ref_infos:
#     <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/scm.py?line=154'>155</a>         return scm.get_ref(str(ref_infos))
# --> <a href='file:///c%3A/Users/aniket.itankar/Desktop/HR_Analytics/env/lib/site-packages/dvc/scm.py?line=156'>157</a> raise RevError(str(exc))
#
# RevError: unknown Git revision 'v2'
